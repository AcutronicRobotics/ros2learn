# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
data_folder = r"/home/elias/Experiments"
file_name = "progress.csv"
file_name2 = "progress_maracollisionorient.csv"
file_name3 = "progress_mara.csv"

# %%
train_data = pd.read_csv(os.path.join(data_folder,file_name))
train_data2 = pd.read_csv(os.path.join(data_folder,file_name2))
train_data3 = pd.read_csv(os.path.join(data_folder,file_name3))
train_data.head()
# Out:
#    approxkl  clipfrac  eplenmean    eprewmean  eprewsem  explained_variance  \
# 0  0.006584  0.084131     2048.0 -2001.691554  0.000000            0.030949
# 1  0.006365  0.077686     2048.0 -1996.164571  5.526982            0.139721
# 2  0.008203  0.109521     2048.0 -1999.255962  6.283185            0.006423
# 3  0.007630  0.100342     2048.0 -1999.082465  5.449690            0.044185
# 4  0.005030  0.055566     2048.0 -1998.249346  5.151276            0.015312
#
#    fps  nupdates  policy_entropy  policy_loss  serial_timesteps  time_elapsed  \
# 0  241         1         8.48369    -0.007888              2048      8.488838
# 1  252         2         8.44473    -0.007205              4096     16.807193
# 2  243         3         8.41475    -0.009661              6144     25.230748
# 3  236         4         8.38895    -0.008323              8192     33.896762
# 4  228         5         8.36677    -0.005640             10240     42.864197
#
#    total_timesteps  value_loss
# ...

# %%
plt.figure()
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1, 2, 1)
#ax.plot(train_data.filter(items=["eprewmean"], axis = 1))
#ax.plot(train_data2.filter(items=["eprewmean"], axis = 1))
ax.plot(train_data3.filter(items=["eprewmean"], axis = 1))
ax.set_xlabel("Mean Total Reward")
ax.set_ylabel('Episode Number')
ax.set_title("Mean Reward evolution")
ax1 = fig.add_subplot(1, 2, 2)
#ax1.plot(train_data.filter(items=["policy_entropy"], axis = 1))
#ax1.plot(train_data2.filter(items=["policy_entropy"], axis = 1))
ax1.plot(train_data3.filter(items=["policy_entropy"], axis = 1))
ax1.set_xlabel("Episode Entropy")
ax1.set_ylabel('Episode Number')
ax1.set_title("Entropy evolution")
# Out:
# Text(0.5, 1.0, 'Entropy evolution')
